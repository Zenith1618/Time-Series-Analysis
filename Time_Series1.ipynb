# %% [markdown]
# <a href="https://colab.research.google.com/github/Zenith1618/Time-Series-Analysis/blob/main/Time_Series1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df_tesla = pdr.DataReader('TSLA', 'stooq')

# %%
df_tesla
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2023-09-01  257.2600  259.0794  242.0100  245.0100  132541640
# 2023-08-31  255.9800  261.1800  255.0500  258.0800  108861698
# 2023-08-30  254.2000  260.5100  250.5900  256.9000  121988437
# 2023-08-29  238.5800  257.4800  237.7700  257.1800  134047603
# 2023-08-28  242.5800  244.3800  235.3500  238.8200  107673727
# ...              ...       ...       ...       ...        ...
# 2018-09-10   18.2173   19.0687   18.0667   19.0333  214252920
# 2018-09-07   17.3400   17.8900   16.8170   17.5493  337378965
# 2018-09-06   18.9867   19.4113   18.5920   18.7300  112211400
# 2018-09-05   19.0033   19.1187   18.4787   18.7160  115812315
# 2018-09-04   19.7960   19.8793   19.2000   19.2633  125257035
#
# [1258 rows x 5 columns]

# %% [markdown]
# **Simple Moving Average(SMA):** To do smoothening the garph
#
# >
#
# >

# %%
df_tesla['Open'].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open: 10 days rolling'] = df_tesla['Open'].rolling(window = 10, min_periods=1).mean()

# %%
df_tesla[['Open','Open: 10 days rolling']].plot(xlim = ['2021-01-01','2022-01-01'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open: 30 days rolling'] = df_tesla['Open'].rolling(window = 30, min_periods=1).mean()
df_tesla['Open: 50 days rolling'] = df_tesla['Open'].rolling(window = 50, min_periods=1).mean()

# %%
df_tesla[['Open','Open: 10 days rolling','Open: 30 days rolling','Open: 50 days rolling']].plot(xlim = ['2021-01-01','2022-01-01'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# **Cumulative Moving Average(CMA)**

# %%
# Using Function Expanding

df_tesla['Open'].expanding().mean().plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# **Exponential Moving Average(EMA)**

# %%
# Let the smoothening factor(alpha: hyperparameter) be 0.1

df_tesla['EMA_0.1'] = df_tesla['Open'].ewm(alpha=0.1, adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1']].plot(xlim = ['2021-01-01','2022-01-01'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['EMA_0.3'] = df_tesla['Open'].ewm(alpha=0.3, adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1', 'EMA_0.3']].plot(xlim = ['2021-01-01','2022-01-01'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# **Exponential Weighted Moving Average(EWMA)**: Check Notebook

# %%
df_tesla['EMA_5days'] = df_tesla['Open'].ewm(span=5, adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1', 'EMA_5days']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>
